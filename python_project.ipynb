# %% [markdown]
# # Python Programming: Final Project
#
#
# First of all, I want to congratulate you for making it this far! We know we've packed a lot of knowledge into a relatively short time! All of you did a great job!
#
# ---
#
# I would like you to have something tangible to show off from this amazing course, so let's use your newly acquired skills in this project.
#
# In this project, you are going to work with a very famous and real dataset on [Breast Cancer Wisconsin (Diagnostic)](https://www.kaggle.com/uciml/breast-cancer-wisconsin-data/data). The dataset is available on kaggle and originally belong to [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Wisconsin+%28Diagnostic%29).<br>
#
# ---
#
# ## Deliverables
#
# You are encouraged to work in groups (ideal size of a group is 3). Each group has to present their finding and they will be given 10 mins to talk.
#
# ### Requirements
#
# Your final presentation **must** include:
#
# 1. Data  exploration
#     - Get creative and apply data exploration in order to retrieve meaningful and correct information. Think how the features are helping to diagnose the type of cancer. Use summary statistics and explore the data to understand other potential measures.
# 2. Data displayed in a minimum of 5 different visualizations.
#     - Take care that they're the best choice of visualizations for the data and are easy to comprehend. Use appropriate labels.
# 3. Cleaning the data — handling of NULL values or other potential errors in the data.
# 4. Core Python topics. At minimum:
#       - Dictionaries *or* sets *or* tuples (if needed).
#       - Using of different libraries: Numpy, Pandas, matplotlib, seaborn etc
#       - Basic debugging, such as a `try-except` block *(only if necessary)*.
#       - Use list comprehension, lambda expression and functions (if needed).
#       - User input *or* reading from a file.
# 5. Comments ate very important, so another team member can easily see what you have done, well documented projects are always appreciated.
# 6. Python style and DocString style at appropriate places.
#
#
# ### Resources
#
# #### Suggested Ways to Get Started
#
# * **Begin with the end in mind.** Know where you want to go by planning ahead. Define the problem and don't waste time building things you don't need. [Here is the information on your dataset on kaggle](https://www.kaggle.com/uciml/breast-cancer-wisconsin-data)
# * **Read the docs** for whatever technologies or datasets you use. Most of the time, there is a tutorial that you can follow! This isn't always the case, however, learning to read documentation is crucial to your success as a developer.
# * **Write `pseudocode` before you write actual code.** Take a pen and paper, thinking through the logic of something is always helpful.
#
# #### Additional Resources
#
# - An [extremely helpful debugging flowchart](https://www.dropbox.com/s/cqsxfws52gulkyx/drawing.pdf).
# - The [Python Docs](https://docs.python.org).
# - [Keyword `args`](http://treyhunner.com/2018/04/keyword-arguments-in-python/).
# - [`args` and `kwargs`](https://www.digitalocean.com/community/tutorials/how-to-use-args-and-kwargs-in-python-3).
# - [Sets on a Python Tutorial Website](https://www.learnpython.org/en/Sets)).
# - [Tuples](http://openbookproject.net/thinkcs/python/english3e/tuples.html).
#
#
# ---
#
# ## Evaluation
#
# Your project will be evaluated based on the rubric below.
#
# ### Rubric
#
# | Score | Expectations |
# | ----- | ---------------------------------------------------- |
# | 0 | Incomplete. |
# | 1 | Does not meet expectations. |
# | 2 | Meets expectations, good job! |
# | 3 | Exceeds expectations, you wonderful creature, you! |
#
#
# A zero-to-three grading scale may not intuitively make sense, so here is an example using the criteria as if your assignment were to cook a pizza:
#
# Criteria | **0** Incomplete. | **1** Does not meet expectations. | **2** Meets expectations. | **3**  Exceeds expectations. |
# :--- | :--- | :--- | :--- | :---
# Crust | No crust present. Submission is just cheese and sauce on a plate. | Pizza has a crust, but it is raw. | Crust is cooked thoroughly.| Crust is golden brown and just thin enough without being too thick.
# Cheese | No cheese present. | Cheese is made of soy. | Cheese covers the pizza from edge to edge. | Cheese is delicious, plentiful, and melted to perfection.

# %%
# let's do some imports first
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid') # just optional!
# %matplotlib inline

#Setting display format to retina in matplotlib to see better quality images.
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')

# Lines below are just to ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
bcd=pd.read_csv('Breast_Cancer_Diagnostic.csv')

# %%
bcd.shape
# Out:
# (569, 32)

# %%
bcd.head()
# Out:
#          id diagnosis  radius_mean texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99            ?          122.80     1001.0
# 1    842517         M        20.57        17.77          132.90     1326.0
# 2  84300903         M        19.69        21.25          130.00     1203.0
# 3  84348301         M        11.42        20.38           77.58      386.1
# 4  84358402         M        20.29        14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# ...

# %%
bcd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
# id                         569 non-null int64
# diagnosis                  569 non-null object
# radius_mean                569 non-null float64
# texture_mean               568 non-null object
# perimeter_mean             569 non-null float64
# area_mean                  569 non-null float64
# smoothness_mean            569 non-null float64
# compactness_mean           569 non-null float64
# concavity_mean             568 non-null float64
# concave points_mean        569 non-null float64
# symmetry_mean              566 non-null float64
# fractal_dimension_mean     565 non-null float64
# radius_se                  569 non-null float64
# texture_se                 569 non-null float64
# perimeter_se               569 non-null float64
# area_se                    569 non-null float64
# smoothness_se              567 non-null float64
# ...

# %%
bcd.describe()
# Out:
#                  id  radius_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292       91.969033   654.889104
# std    1.250206e+08     3.524049       24.298981   351.914129
# min    8.670000e+03     6.981000       43.790000   143.500000
# 25%    8.692180e+05    11.700000       75.170000   420.300000
# 50%    9.060240e+05    13.370000       86.240000   551.100000
# 75%    8.813129e+06    15.780000      104.100000   782.700000
# max    9.113205e+08    28.110000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      568.000000           569.000000
# mean          0.096360          0.104341        0.088590             0.048919
# std           0.014064          0.052813        0.079633             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
bcd.isnull().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               1
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             1
# concave points_mean        0
# symmetry_mean              3
# fractal_dimension_mean     4
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              2
# compactness_se             2
# concavity_se               5
# concave points_se          0
# symmetry_se                1
# fractal_dimension_se       0
# radius_worst               1
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          3
# concavity_worst            3
# concave points_worst       2
# symmetry_worst             2
# fractal_dimension_worst    2
# ...

# %%
bcd.sample()
# Out:
#            id diagnosis  radius_mean texture_mean  perimeter_mean  area_mean  \
# 429  90769602         B        12.72        17.67           80.98      501.3
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 429          0.07896           0.04522         0.01402              0.01835
#
#      ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 429  ...         13.82          20.96            88.87       586.8
#
#      smoothness_worst  compactness_worst  concavity_worst  \
# 429            0.1068            0.09605          0.03469
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 429               0.03612          0.2165                  0.06025
#
# [1 rows x 32 columns]

# %%
by_dia = bcd.groupby('diagnosis')['id'].count()
by_dia
# Out:
# diagnosis
# B    357
# M    212
# Name: id, dtype: int64

# %%
bcd['id'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Good luck!

# %%
bcd['diagnosis'].unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
null_data = bcd[bcd.isnull().any(axis=1)]
null_data
# Out:
#            id diagnosis  radius_mean texture_mean  perimeter_mean  area_mean  \
# 8      844981         M       13.000        21.82           87.50      519.8
# 9    84501001         M       12.460        24.04           83.97      475.9
# 10     845636         M       16.020        23.24          102.70      797.8
# 11   84610002         M       15.780        17.89          103.60      781.0
# 13     846381         M       15.850        23.95          103.70      782.7
# 14   84667401         M       13.730        22.61           93.60      578.3
# 15   84799002         M       14.540        27.54           96.73      658.8
# 17   84862001         M       16.130          NaN          108.10      798.8
# 19    8510426         B       13.540        14.36           87.46      566.3
# 22    8511133         M       15.340        14.26          102.50      704.4
# 38     855133         M       14.990         25.2           95.54      698.8
# ...

# %%
bcd['texture_mean']=pd.to_numeric(bcd['texture_mean'],errors='coerce')

# %%
bcd.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99           NaN          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
null_data = bcd[bcd.isnull().any(axis=1)]
null_data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M       17.990           NaN          122.80     1001.0
# 8      844981         M       13.000         21.82           87.50      519.8
# 9    84501001         M       12.460         24.04           83.97      475.9
# 10     845636         M       16.020         23.24          102.70      797.8
# 11   84610002         M       15.780         17.89          103.60      781.0
# 13     846381         M       15.850         23.95          103.70      782.7
# 14   84667401         M       13.730         22.61           93.60      578.3
# 15   84799002         M       14.540         27.54           96.73      658.8
# 17   84862001         M       16.130           NaN          108.10      798.8
# 19    8510426         B       13.540         14.36           87.46      566.3
# 22    8511133         M       15.340         14.26          102.50      704.4
# ...

# %%
bcd.isnull().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               2
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             1
# concave points_mean        0
# symmetry_mean              3
# fractal_dimension_mean     4
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              2
# compactness_se             2
# concavity_se               5
# concave points_se          0
# symmetry_se                1
# fractal_dimension_se       0
# radius_worst               1
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          3
# concavity_worst            3
# concave points_worst       2
# symmetry_worst             2
# fractal_dimension_worst    2
# ...

# %%
bcd['symmetry_mean'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 564    False
# 565    False
# 566    False
# 567    False
# 568    False
# Name: symmetry_mean, Length: 569, dtype: bool

# %%
bcd.loc[bcd.isnull().any(axis=1)]
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M       17.990           NaN          122.80     1001.0
# 8      844981         M       13.000         21.82           87.50      519.8
# 9    84501001         M       12.460         24.04           83.97      475.9
# 10     845636         M       16.020         23.24          102.70      797.8
# 11   84610002         M       15.780         17.89          103.60      781.0
# 13     846381         M       15.850         23.95          103.70      782.7
# 14   84667401         M       13.730         22.61           93.60      578.3
# 15   84799002         M       14.540         27.54           96.73      658.8
# 17   84862001         M       16.130           NaN          108.10      798.8
# 19    8510426         B       13.540         14.36           87.46      566.3
# 22    8511133         M       15.340         14.26          102.50      704.4
# ...

# %%
df_null = bcd.isnull().unstack()
t = df_null[df_null]
t
# Out:
# texture_mean             0      True
#                          17     True
# concavity_mean           22     True
# symmetry_mean            13     True
#                          14     True
#                          15     True
# fractal_dimension_mean   9      True
#                          10     True
#                          11     True
#                          13     True
# smoothness_se            38     True
#                          93     True
# compactness_se           40     True
#                          338    True
# concavity_se             83     True
#                          84     True
#                          86     True
#                          87     True
#                          349    True
# symmetry_se              358    True
# radius_worst             344    True
# compactness_worst        8      True
#                          9      True
#                          356    True
# concavity_worst          10     True
# ...

# %%
pd.set_option('display.max_columns', 32)

# %%
bcd.loc[bcd.isnull().any(axis=1)]
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M       17.990           NaN          122.80     1001.0
# 8      844981         M       13.000         21.82           87.50      519.8
# 9    84501001         M       12.460         24.04           83.97      475.9
# 10     845636         M       16.020         23.24          102.70      797.8
# 11   84610002         M       15.780         17.89          103.60      781.0
# 13     846381         M       15.850         23.95          103.70      782.7
# 14   84667401         M       13.730         22.61           93.60      578.3
# 15   84799002         M       14.540         27.54           96.73      658.8
# 17   84862001         M       16.130           NaN          108.10      798.8
# 19    8510426         B       13.540         14.36           87.46      566.3
# 22    8511133         M       15.340         14.26          102.50      704.4
# ...

# %%
sns.countplot(x='diagnosis', data=bcd)

# %%
sns.countplot(x='radius_mean', hue='diagnosis',data=bcd, palette='coolwarm')

# %%
bcd.plot.box(vert=False)

# %%
plt.figure(figsize=(10, 6)) # setting the figure size, its subjective
sns.boxplot(x='diagnosis',y='radius_mean',data=bcd, palette='rainbow')

# %%
plt.figure(figsize=(10, 6)) # setting the figure size, its subjective
sns.boxplot(x='diagnosis',y='area_mean',data=bcd, palette='rainbow')

# %%
plt.figure(figsize=(10, 6)) # setting the figure size, its subjective
sns.boxplot(x='diagnosis',y='radius_mean',data=bcd, palette='rainbow')

# %%
sorted(bcd)
# Out:
# ['area_mean',
#  'area_se',
#  'area_worst',
#  'compactness_mean',
#  'compactness_se',
#  'compactness_worst',
#  'concave points_mean',
#  'concave points_se',
#  'concave points_worst',
#  'concavity_mean',
#  'concavity_se',
#  'concavity_worst',
#  'diagnosis',
#  'fractal_dimension_mean',
#  'fractal_dimension_se',
#  'fractal_dimension_worst',
#  'id',
#  'perimeter_mean',
#  'perimeter_se',
#  'perimeter_worst',
#  'radius_mean',
#  'radius_se',
#  'radius_worst',
#  'smoothness_mean',
#  'smoothness_se',
#  'smoothness_worst',
#  'symmetry_mean',
#  'symmetry_se',
#  'symmetry_worst',
#  'texture_mean',
#  'texture_se',
#  'texture_worst']

# %%
bcd['area_mean'].hist(bins=30);

# %%
bcd.plot.hist(alpha = 0.5)

# %%
sns.lmplot(x = 'radius_mean', y = 'concavity_mean', hue = 'diagnosis', data = bcd)

# %%
<section data-markdown>
	<textarea data-template>
		## Page title

		A paragraph with some text and a [link](http://hakim.se).
	</textarea>
</section>
# Out:
#   File "<ipython-input-35-2693bf39714e>", line 1
#     <section data-markdown>
#     ^
# SyntaxError: invalid syntax
